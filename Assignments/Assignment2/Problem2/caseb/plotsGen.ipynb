# %%
import matplotlib.pyplot as plt

# %%
import csv
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv('stats.csv', usecols=['numThreads','serialTime','parallelTime'])

# %%
df.plot(x="numThreads", title='Outer two loops parallelized')

# %%
df = pd.read_csv('stats.csv', usecols=['numThreads','speedUp'])

# %%
df.plot(x="numThreads", title='Speedup - Outer two loops parallelized')
